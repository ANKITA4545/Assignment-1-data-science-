# %% [markdown]
# <a href="https://colab.research.google.com/github/ANKITA4545/Assignment-1-data-science-/blob/main/pdf13(pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Version of pandas
pd.__version__
# Out:
# '2.2.2'

# %%
number_series = pd.Series([2, 3, 5, 6, 8])
print (number_series)
# Out:
# 0    2
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
number_series = pd.Series([2, 3, 5, 6, 8],index=['a', 'b', 'd','e','f'],name="Number")
print (number_series)
# Out:
# a    2
# b    3
# d    5
# e    6
# f    8
# Name: Number, dtype: int64

# %%
print (number_series[0])
print (number_series['a'])
# Out:
# 2
# 2
# <ipython-input-9-2e7569b4f3b8>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print (number_series[0])

# %%
some_2D_array = np.random.randint(4, 6,(3,4))

first_dataframe = pd.DataFrame(some_2D_array , columns=['Akshay', 'Devashish', 'Divy', 'Monika'])
first_dataframe
# Out:
#    Akshay  Devashish  Divy  Monika
# 0       4          4     4       4
# 1       5          5     4       5
# 2       5          4     5       5

# %%
import pandas as pd

another_dataframe = pd.DataFrame(some_2D_array, columns=['A','B','C','D'],index = ['First', 'Second', 'Third'])
another_dataframe
# Out:
#         A  B  C  D
# First   4  4  4  4
# Second  5  5  4  5
# Third   5  4  5  5

# %%
list_of_lists = [['Amar', 10], ['Akbar', 15], ["Anthony", 14]]

# Create the pandas DataFrame
df = pd.DataFrame(list_of_lists, columns = ['Name', 'Age'])

# Print dataframe
df
df = pd.DataFrame(list_of_lists, columns = ['Name', 'Age'])

# Print dataframe
df
# Out:
#       Name  Age
# 0     Amar   10
# 1    Akbar   15
# 2  Anthony   14

# %%
employee_dict = {"Employee Name":['Rajeev', 'Sumit', 'Aviral'], 'Income':[20000, 14900, 90000]}

# Create DataFrame
employee_df = pd.DataFrame(employee_dict)

# Print the d
print(employee_df)
employee_df = pd.DataFrame(employee_dict)

# Print the d
# Out:
#   Employee Name  Income
# 0        Rajeev   20000
# 1         Sumit   14900
# 2        Aviral   90000

# %%
series_dict = {'First Series' : pd.Series([10, 26, 30, 40]),
"Second Series" : pd.Series([1, 20, 38, 40])}

# Create the Dataframe using the dictionary
df = pd.DataFrame(series_dict)

# Print the dataframe

df
# Create the Dataframe using the dictionary
df = pd.DataFrame(series_dict)

# Print the dataframe

df
# Out:
#    First Series  Second Series
# 0            10              1
# 1            26             20
# 2            30             38
# 3            40             40

# %%
list_of_dicts = [{'a': 1, 'b': 2, 'c':3}, {'a':10, 'b': 20, 'c': 30}]

# Create the DataFrame
import pandas as pd
df = pd.DataFrame(list_of_dicts)

# Print the dataframe
df
df = pd.DataFrame(list_of_dicts)

# Print the dataframe
df
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30

# %%
list_of_dicts = [{'a': 2, 'c':3}, {'a': 10, 'b': 20, 'c': 30}]

import pandas as pd
df = pd.DataFrame(list_of_dicts, index =['first', "second"])

df

df
# Out:
#          a   c     b
# first    2   3   NaN
# second  10  30  20.0

# %%
actor_names = ['Ryan Reynolds', 'Benedict Cumberbatch', 'Robert Downey Jr.', 'Chris Evans']

# List of their ages
actor_ages = [48,62,54,np.nan ]

# Get the list of tuples by zipping the two lists together
list_of_tuples = list(zip(actor_names, actor_ages))

# Converting the list of tuples into pandas Dataframe
actor_df = pd.DataFrame(list_of_tuples, columns = ["Name", "Age"])

# Print the dataframe
actor_df
actor_ages = [48,62,54,np.nan ]

# Get the list of tuples by zipping the two lists together
list_of_tuples = list(zip(actor_names, actor_ages))
actor_names = ['Ryan Reynolds', 'Benedict Cumberbatch', 'Robert Downey Jr.', 'Chris Evans']

# List of their ages
actor_ages = [48,62,54,np.nan ]

# Get the list of tuples by zipping the two lists together
list_of_tuples = list(zip(actor_names, actor_ages))

# Converting the list of tuples into pandas Dataframe
actor_df = pd.DataFrame(list_of_tuples, columns = ["Name", "Age"])

# Print the dataframe
actor_df
actor_ages = [48,62,54,np.nan ]

# Get the list of tuples by zipping the two lists together
list_of_tuples = list(zip(actor_names, actor_ages))

# Converting the list of tuples into pandas Dataframe
actor_df = pd.DataFrame(list_of_tuples, columns = ["Name", "Age"])

# Print the dataframe
actor_df
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  62.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
list(actor_df. index)
# Out:
# [0, 1, 2, 3]

# %%
import pandas as pd
import numpy as np

our_array = np.random.randn(3, 5)

df = pd.DataFrame(our_array, columns=['A','B','C','D','E'])
df
# Out:
#           A         B         C         D         E
# 0 -0.152876 -0.589413 -0.044168  0.526919 -0.180685
# 1 -0.358451 -0.347097 -1.036756 -0.766646 -0.598146
# 2  0.097247  0.324885  0.965510  1.794300 -1.205596

# %%
df.head()
# Out:
#           A         B         C         D         E
# 0 -0.152876 -0.589413 -0.044168  0.526919 -0.180685
# 1 -0.358451 -0.347097 -1.036756 -0.766646 -0.598146
# 2  0.097247  0.324885  0.965510  1.794300 -1.205596

# %%
df.head(1)
# Out:
#           A         B         C         D         E
# 0 -0.152876 -0.589413 -0.044168  0.526919 -0.180685

# %%
df.tail()
# Out:
#           A         B         C         D         E
# 0 -0.152876 -0.589413 -0.044168  0.526919 -0.180685
# 1 -0.358451 -0.347097 -1.036756 -0.766646 -0.598146
# 2  0.097247  0.324885  0.965510  1.794300 -1.205596

# %%
df.tail(1)
# Out:
#           A         B        C       D         E
# 2  0.097247  0.324885  0.96551  1.7943 -1.205596

# %%
list(df.columns)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
list(actor_df.columns)
# Out:
# ['Name', 'Age']

# %%
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  62.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
actor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 196.0+ bytes

# %%
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  62.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
dfi=actor_df.rename(columns = {'Name':'Actor Name','Age':'Actor Age'}, inplace=False) #Fixed typo in Age column name.
dfi # Use 'dfi' instead of 'df1' to display the DataFrame.
# Out:
#              Actor Name  Actor Age
# 0         Ryan Reynolds       48.0
# 1  Benedict Cumberbatch       62.0
# 2     Robert Downey Jr.       54.0
# 3           Chris Evans        NaN

# %%
employee_df
# Out:
#   Employee Name  Income
# 0        Rajeev   20000
# 1         Sumit   14900
# 2        Aviral   90000

# %%
employee_df.rename(columns = {'Employee Name':'Name'}, inplace=True)

employee_df
# Out:
#      Name  Income
# 0  Rajeev   20000
# 1   Sumit   14900
# 2  Aviral   90000

# %%
employee_df.rename(columns = {'Employee Name':'Name'}, inplace=True)

employee_df
# Out:
#      Name  Income
# 0  Rajeev   20000
# 1   Sumit   14900
# 2  Aviral   90000
